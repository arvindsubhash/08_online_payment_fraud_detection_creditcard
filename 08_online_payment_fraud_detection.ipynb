# %% [markdown]
# # introduction

# %% [markdown]
# Online payments is the most popular transaction method in the world today. However, with an increase in online payment also comes a rise in payment fraud. The objectives of the study is to indintyfy fraudulent and non fraudulent payments. the dataset is collect from kaggle which containes historical inforamtion about fraudulent transaction , which can be used to datect fraudin online payments.

# %% [markdown]
# The dataset consits of 10 varibles:

# %% [raw]
# .setp: represent a unit of time where 1 step equals 1 hour
# .type: type of online transaction
# .amount: the amount of the transation
# .nameOrig: customer starting the transaction
# .oldbalanceOrg: balance before the transaction
# .newbalanceOrg: balance after the transaction
# . namedest: recipient of the transaction
# . oldbalancedest: intial balance of recipient after the trancsation
# .newbalancedest: the new balance of recipient after the
# .isfraud: fraud transaction

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt  
# %matplotlib inline
import seaborn as sns 
import scipy as sp 
from tabulate import tabulate

# %%
df = pd.read_csv('C:\\Users\\arvin\\downloads\\creditcards.csv')

# %%
df.head(40)
# Out:
#     Time        V1        V2        V3        V4        V5        V6  \
# 0    0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1    0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2    1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3    1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4    2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# 5    2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728
# 6    4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 7    7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118
# 8    7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818
# 9    9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761
# 10  10.0  1.449044 -1.176339  0.913860 -1.375667 -1.971383 -0.629152
# 11  10.0  0.384978  0.616109 -0.874300 -0.094019  2.924584  3.317027
# 12  10.0  1.249999 -1.221637  0.383930 -1.234899 -1.485419 -0.753230
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.sample(10)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 39595    39897.0  1.107829 -0.308617  1.096717  0.693355 -0.900647  0.219585
# 239624  150193.0 -0.430934  0.536392  0.844872 -0.085958 -0.532654 -0.020152
# 218769  141453.0 -1.203610  0.097851  0.246869 -4.886161  1.766162  3.432716
# 21806    31867.0  1.342582 -0.282167 -0.990285 -1.242847  1.741148  3.234212
# 261869  160219.0  0.058478 -0.087449  0.343170 -1.774777 -0.863131  0.098161
# 264625  161510.0 -0.508648  1.057936 -0.709024 -0.696124  1.140666 -0.989838
# 104773   69223.0 -0.225811  0.448364  0.256965 -0.987349  2.416966  3.775268
# 119424   75439.0 -1.426928  0.646295  1.210540 -1.622925  0.464642 -0.329375
# 171338  120597.0 -0.229110 -0.058617  0.718283 -1.797004 -0.277196 -0.342112
# 15730    27160.0 -0.781890  0.503097  2.323885 -0.513395 -0.486961 -0.571650
#
#               V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# . There are no missing values.

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
rows,cols=df.shape
print(f'There are {rows} Rows and {cols} Columns')
# Out:
# There are 284807 Rows and 31 Columns

# %% [markdown]
# std is very high

# %%
data_corr=df.corr().style.background_gradient(cmap='twilight')
data_corr
# Out:
# <style type="text/css">
# ...

# %%
plt.figure(figsize=(14, 14))
sns.heatmap(cbar=True,data=df.corr(),cmap='tab20b')
plt.show()

# %%
df.keys()
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %% [markdown]
# # prepare the Data

# %%
from sklearn .model_selection import train_test_split
x=df.drop(columns={'Class'})
y=df['Class']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %% [markdown]
# # logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression()
LR.fit(x_train, y_train)
y_pred=LR.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm= confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import accuracy_score
print('logistic regression accuracy :',accuracy_score(y_test,y_pred))
# Out:
# logistic regression accuracy : 0.9992626663389628

# %% [markdown]
# naive byes

# %%
from sklearn.naive_bayes import GaussianNB
NB=GaussianNB()
NB.fit(x_train,y_train)
y_pred2=NB.predict(x_test)
################################
cm2=confusion_matrix(y_test,y_pred2)
sns.heatmap(cm2, annot=True)
###############################
print('naive byes accuracy :',accuracy_score(y_test,y_pred2))
# Out:
# naive byes accuracy : 0.9775113233383659

# %%
from sklearn.tree import DecisionTreeClassifier
tree= DecisionTreeClassifier()
tree.fit(x_train,y_train)
y_pred3=tree.predict(x_test)

cm3=confusion_matrix(y_test,y_pred3)
sns.heatmap(cm3,annot=True)

print('Decission Tree accuracy :',accuracy_score(y_test,y_pred3))
# Out:
# Decission Tree accuracy : 0.9992451107756047

# %% [markdown]
# # Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
RF= RandomForestClassifier()
RF.fit(x_train,y_train)
y_pred4=RF.predict(x_test)

cm4=confusion_matrix(y_test,y_pred4)
sns.heatmap(cm4, annot=True)

print('Random Forest accuracy :',accuracy_score(y_test,y_pred4))

# %%
accuracies=[accuracy_score(y_test,y_pred),accuracy_score(y_test,y_pred2),accuracy_score(y_test,y_pred3),
           accuracy_score(y_test,y_pred4)]
best_acc=max(accuracies)
print(best_acc)
# Out:
# 0.9996137776061234
